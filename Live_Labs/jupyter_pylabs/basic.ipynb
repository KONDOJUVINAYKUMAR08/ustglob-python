# %%
emails = "a@test.com"
#print just domain name 
dom=emails.split("@")[1]
name=emails.split("@")[0]
print("Domain name  =",dom)
print("Name         =",name)
# Out:
# Domain name  = test.com
# Name         = a

# %%
str="natarajan murugadoss"
fname,lname=str.split(" ")
print(fname)
print(lname)
# Out:
# natarajan
# murugadoss
